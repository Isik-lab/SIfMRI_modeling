# %%
import nibabel as nib
from nilearn import plotting, datasets
import numpy as np
import os

# %%
top_path = '/Users/emcmaho7/Dropbox/projects/SI_fmri/SIfMRI_modeling/data/raw/nsd_rois/subj01'
roi_file = f'{top_path}/rh.streams.nii.gz'
anat_file = f'{top_path}/T1.nii.gz'
roi = nib.load(roi_file)
anat = nib.load(anat_file)

# %%
plotting.plot_roi(roi, bg_img=anat, cut_coords=(0, -8, 3))
